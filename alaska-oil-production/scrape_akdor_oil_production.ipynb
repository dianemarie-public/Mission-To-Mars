# %%
from gazpacho import get, Soup

# %%
url = "https://tax.alaska.gov/programs/oil/production/ans.aspx?"
url
# Out:
# 'https://tax.alaska.gov/programs/oil/production/ans.aspx?'

# %%
html = get(url)
# html

# %%
soup = Soup(html)
# soup

# %%
list = soup.find('option')[1:]
# list

# %%
length = len(list)
length
# Out:
# 249

# %%
urls = []
urls
# Out:
# []

# %%
for i in range(length):
    options = list[i].attrs['value']
    urls.append(url + options)

len(urls)
# Out:
# 249

# %%
# urls

# %%
import pandas as pd

# %%
for url in urls:
    df = pd.read_html(url)[6]
    df = df.loc[0:]
    df[1] = pd.to_numeric(df[1],errors='coerce')
    df[2] = pd.to_numeric(df[2],errors='coerce')
    df[3] = pd.to_numeric(df[3],errors='coerce')
    df[4] = pd.to_numeric(df[4],errors='coerce')
    df[5] = pd.to_numeric(df[5],errors='coerce')
    df[6] = pd.to_numeric(df[6],errors='coerce')
    df[7] = pd.to_numeric(df[7],errors='coerce')
    del df[8]
    del df[9]
    del df[10]
    del df[11]
    del df[12]
    df = df.dropna(how='any')
    df = df[df[0] != 'Average']
    df.to_csv('akdor_oil_production.csv', mode='a', header=["Date", "PrudhoeBay", "Kaparuk", "Endicott", "Lisburne", "Alpine", "ANS", "Inventories"], index=False)

# %%
# Read scraped data file into Pandas

# %%
data_df = pd.read_csv('akdor_oil_production.csv')
# Out:
# C:\Users\diane\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (1,2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_df = data_df.rename(columns={'1':'PrudhoeBay','2':'Kuparuk','3':'Endicott','4':'Lisburne','5':'Alpine', '6':'ANS','7':'Inventories'})

# %%
data_df.dropna(how='any')
# Out:
#            Date  PrudhoeBay  Kuparuk  Endicott  Lisburne  Alpine     ANS  \
# 0      9/1/2021      292022    88063         0     21068   49002  450155
# 1      9/2/2021      298546    92461         0     20472   48452  459930
# 2      9/3/2021      289929    94146         0     18449   47901  450424
# 3      9/4/2021      296408    94549         0     18157   47449  456562
# 4      9/5/2021      298994    94469         0     20177   47702  461343
# ...         ...         ...      ...       ...       ...     ...     ...
# 84776      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84777      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84778      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84779      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84780      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
#
#        Inventories
# 0          1623874
# 1          1530847
# 2          1234895
# 3          1624191
# 4          1388480
# ...            ...
# 84776  Inventories
# 84777  Inventories
# 84778  Inventories
# 84779  Inventories
# 84780  Inventories
#
# [84781 rows x 8 columns]

# %%
data_df[data_df["Date"].str.contains("Date")==False]
# Out:
#              Date PrudhoeBay   Kuparuk Endicott Lisburne   Alpine       ANS  \
# 0        9/1/2021     292022     88063        0    21068    49002    450155
# 1        9/2/2021     298546     92461        0    20472    48452    459930
# 2        9/3/2021     289929     94146        0    18449    47901    450424
# 3        9/4/2021     296408     94549        0    18157    47449    456562
# 4        9/5/2021     298994     94469        0    20177    47702    461343
# ...           ...        ...       ...      ...      ...      ...       ...
# 84766  11/26/2001   546298.0  221064.0  54989.0  32918.0  73456.0  102358.0
# 84767  11/27/2001   528981.0  221551.0  54900.0  32800.0  75764.0  103260.0
# 84768  11/28/2001   544149.0  221362.0  54777.0  32606.0  74612.0  102419.0
# 84769  11/29/2001   534557.0  218930.0  54534.0  33101.0  73444.0  101061.0
# 84770  11/30/2001   544404.0  211357.0  53523.0  26911.0  72722.0  101538.0
#
#       Inventories
# 0         1623874
# 1         1530847
# 2         1234895
# 3         1624191
# 4         1388480
# ...           ...
# 84766     10294.0
# 84767     25169.0
# 84768      9984.0
# 84769     14044.0
# 84770     18516.0
#
# [84229 rows x 8 columns]

# %%
data_df = data_df[data_df["Date"].str.contains("Date")==False]
data_df
# Out:
#              Date PrudhoeBay   Kuparuk Endicott Lisburne   Alpine       ANS  \
# 0        9/1/2021     292022     88063        0    21068    49002    450155
# 1        9/2/2021     298546     92461        0    20472    48452    459930
# 2        9/3/2021     289929     94146        0    18449    47901    450424
# 3        9/4/2021     296408     94549        0    18157    47449    456562
# 4        9/5/2021     298994     94469        0    20177    47702    461343
# ...           ...        ...       ...      ...      ...      ...       ...
# 84766  11/26/2001   546298.0  221064.0  54989.0  32918.0  73456.0  102358.0
# 84767  11/27/2001   528981.0  221551.0  54900.0  32800.0  75764.0  103260.0
# 84768  11/28/2001   544149.0  221362.0  54777.0  32606.0  74612.0  102419.0
# 84769  11/29/2001   534557.0  218930.0  54534.0  33101.0  73444.0  101061.0
# 84770  11/30/2001   544404.0  211357.0  53523.0  26911.0  72722.0  101538.0
#
#       Inventories
# 0         1623874
# 1         1530847
# 2         1234895
# 3         1624191
# 4         1388480
# ...           ...
# 84766     10294.0
# 84767     25169.0
# 84768      9984.0
# 84769     14044.0
# 84770     18516.0
#
# [84229 rows x 8 columns]

# %%
data_df.dtypes
# Out:
# Date           object
# PrudhoeBay     object
# Kuparuk        object
# Endicott       object
# Lisburne       object
# Alpine         object
# ANS            object
# Inventories    object
# dtype: object

# %%
data_df['PrudhoeBay'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')
data_df['Kuparuk'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')
data_df['Endicott'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')
data_df['Lisburne'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')
data_df['Alpine'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')
data_df['ANS'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')
data_df['Inventories'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')

# %%
data_df
# Out:
#              Date  PrudhoeBay   Kuparuk Endicott Lisburne   Alpine       ANS  \
# 0        9/1/2021    292022.0     88063        0    21068    49002    450155
# 1        9/2/2021    298546.0     92461        0    20472    48452    459930
# 2        9/3/2021    289929.0     94146        0    18449    47901    450424
# 3        9/4/2021    296408.0     94549        0    18157    47449    456562
# 4        9/5/2021    298994.0     94469        0    20177    47702    461343
# ...           ...         ...       ...      ...      ...      ...       ...
# 84766  11/26/2001    546298.0  221064.0  54989.0  32918.0  73456.0  102358.0
# 84767  11/27/2001    528981.0  221551.0  54900.0  32800.0  75764.0  103260.0
# 84768  11/28/2001    544149.0  221362.0  54777.0  32606.0  74612.0  102419.0
# 84769  11/29/2001    534557.0  218930.0  54534.0  33101.0  73444.0  101061.0
# 84770  11/30/2001    544404.0  211357.0  53523.0  26911.0  72722.0  101538.0
#
#       Inventories
# 0         1623874
# 1         1530847
# 2         1234895
# 3         1624191
# 4         1388480
# ...           ...
# 84766     10294.0
# 84767     25169.0
# 84768      9984.0
# 84769     14044.0
# 84770     18516.0
#
# [84229 rows x 8 columns]

# %%
data_df['PrudhoeBay'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20444/1390846439.py in <module>
# ----> 1 data_df['PrudhoeBay'].sum()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10706             **kwargs,
#   10707         ):
# > 10708             return NDFrame.sum(
#   10709                 self, axis, skipna, level, numeric_only, min_count, **kwargs
#   10710             )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in sum(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10444         **kwargs,
#   10445     ):
# > 10446         return self._min_count_stat_function(
#   10447             "sum", nanops.nansum, axis, skipna, level, numeric_only, min_count, **kwargs
#   10448         )
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _min_count_stat_function(self, name, func, axis, skipna, level, numeric_only, min_count, **kwargs)
#   10426                 numeric_only=numeric_only,
#   10427             )
# > 10428         return self._reduce(
#   10429             func,
#   10430             name=name,
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4390                 )
#    4391             with np.errstate(all="ignore"):
# -> 4392                 return op(delegate, skipna=skipna, **kwds)
#    4393
#    4394     def _reindex_indexer(
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      91             try:
#      92                 with np.errstate(invalid="ignore"):
# ---> 93                     return f(*args, **kwargs)
#      94             except ValueError as e:
#      95                 # we want to transform an object array
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in new_func(values, axis, skipna, mask, **kwargs)
#     408             mask = isna(values)
#     409
# --> 410         result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     411
#     412         if datetimelike:
#
# ~\anaconda3\lib\site-packages\pandas\core\nanops.py in nansum(values, axis, skipna, min_count, mask)
#     588         dtype_sum = np.float64  # type: ignore[assignment]
#     589
# --> 590     the_sum = values.sum(axis, dtype=dtype_sum)
#     591     the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     592
#
# ~\anaconda3\lib\site-packages\numpy\core\_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      45 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      46          initial=_NoValue, where=True):
# ---> 47     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      48
#      49 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
