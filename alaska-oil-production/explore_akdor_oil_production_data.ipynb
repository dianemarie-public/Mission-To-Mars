# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt

# %%
# Read scraped data file into Pandas
data_df = pd.read_csv('akdor_oil_production.csv')
# Out:
# C:\Users\diane\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (1,2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data_df = data_df.rename(columns={'1':'PrudhoeBay','2':'Kuparuk','3':'Endicott','4':'Lisburne','5':'Alpine', '6':'ANS','7':'Inventories'})

# %%
data_df.dropna(how='any')
# Out:
#            Date  PrudhoeBay  Kuparuk  Endicott  Lisburne  Alpine     ANS  \
# 0      9/1/2021      292022    88063         0     21068   49002  450155
# 1      9/2/2021      298546    92461         0     20472   48452  459930
# 2      9/3/2021      289929    94146         0     18449   47901  450424
# 3      9/4/2021      296408    94549         0     18157   47449  456562
# 4      9/5/2021      298994    94469         0     20177   47702  461343
# ...         ...         ...      ...       ...       ...     ...     ...
# 84776      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84777      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84778      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84779      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
# 84780      Date  PrudhoeBay  Kaparuk  Endicott  Lisburne  Alpine     ANS
#
#        Inventories
# 0          1623874
# 1          1530847
# 2          1234895
# ...

# %%
data_df = data_df[data_df["Date"].str.contains("Date")==False]
data_df.dtypes
# Out:
# Date           object
# PrudhoeBay     object
# Kuparuk        object
# Endicott       object
# Lisburne       object
# Alpine         object
# ANS            object
# Inventories    object
# dtype: object

# %%
data_df['Date']= pd.to_datetime(data_df['Date'])
data_df['PrudhoeBay'] = pd.to_numeric(data_df['PrudhoeBay'],errors='coerce')
data_df['Kuparuk'] = pd.to_numeric(data_df['Kuparuk'],errors='coerce')
data_df['Endicott'] = pd.to_numeric(data_df['Endicott'],errors='coerce')
data_df['Lisburne'] = pd.to_numeric(data_df['Lisburne'],errors='coerce')
data_df['Alpine'] = pd.to_numeric(data_df['Alpine'],errors='coerce')
data_df['ANS'] = pd.to_numeric(data_df['ANS'],errors='coerce')
data_df['Inventories'] = pd.to_numeric(data_df['Inventories'],errors='coerce')
data_df.dtypes
# Out:
# Date           datetime64[ns]
# PrudhoeBay            float64
# Kuparuk               float64
# Endicott              float64
# Lisburne              float64
# Alpine                float64
# ANS                   float64
# Inventories           float64
# dtype: object

# %%
sns.pairplot(data_df)

# %%
sns.relplot(x=data_df['Date'], y=data_df['PrudhoeBay'], kind='line')

# %%
sns.relplot(x=data_df['Date'], y=data_df['Kuparuk'], kind='line')

# %%
sns.relplot(x=data_df['Date'], y=data_df['Endicott'], kind='line')

# %%
sns.relplot(x=data_df['Date'], y=data_df['Lisburne'], kind='line')

# %%
sns.relplot(x=data_df['Date'], y=data_df['Alpine'], kind='line')

# %%
# help found at https://towardsdatascience.com/working-with-datetime-in-pandas-dataframe-663f7af6c587
data_df['Year'] = data_df['Date'].dt.year
grouped_year = data_df.groupby('Year').sum()
grouped_year
# Out:
#         PrudhoeBay      Kuparuk     Endicott     Lisburne       Alpine  \
# Year
# 2001  2.689450e+08  106940496.0   26360760.0   16222624.0   38131712.0
# 2002  1.439432e+09  612055760.0  148239168.0   86862680.0  191672912.0
# 2003  1.395869e+09  616098560.0  149711808.0   87303552.0  175946008.0
# 2004  1.307331e+09  568178792.0  150001296.0   67873576.0  153455872.0
# 2005  1.225516e+09  527630048.0  128032960.0   60690472.0  125444504.0
# 2006  9.653326e+08  496282952.0  106298728.0   69622680.0   75706008.0
# 2007  9.083496e+08  447832192.0   95950400.0  128689880.0   69462032.0
# 2008  9.201733e+08  425699776.0   94407960.0  109264112.0   96625432.0
# 2009  9.486452e+08  432849632.0   84509744.0   37344920.0   91606032.0
# 2010  9.304696e+08  410380991.0   79835854.0   38415546.0   77413066.0
# 2011  9.856797e+08  439068798.0   68458320.0   47817522.0  115832160.0
# 2012  1.039284e+09  417032405.0   35990428.0   94582444.0  241479384.0
# ...

# %%
sns.displot(grouped_year['PrudhoeBay'], x='Year', kind='hist')

# %%
# data_df['Month'] = data_df['Date'].dt.month
# data_df['Day'] = data_df['Date'].dt.day

# grouped = data_df.groupby(['Year', 'Month', 'Day']).sum()
